# %% [markdown]
# # Homework 3: Visualizing Data with Movies
#
# Name: Eric Long
#
# Date: 9/11/2024
#
# #### Overview
# In this homework, you'll create a movie visualization of a model parameter such as temperature, salinity, velocity, or any other field which may be of interest to you.
#
# As an example, I've provided a movie of circulation in the Equatorial Pacific from the NASA ECCO Version 5 State Estimate. For the purposes of this visualization, I subsetted the Equatorial Pacific is the region between 155-75$^{\circ}$W and $\pm$20$^{\circ}$N.
#
# #### Import Modules
# Import the modules required to access data from netCDF files, plot it, and stitch panels together into a movie:

# %%
# import modules here
import os
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc4
import moviepy.video.io.ImageSequenceClip

# %% [markdown]
# ## Part 1: Download Data
# To begin this exercise, download all of the available data for your variable of interest over the timespan of interest.
#
# For the example provided, I've used daily sea surface temperature data for a given year (2015) from the ECCO Version 5 Alpha output [HERE](https://ecco.jpl.nasa.gov/drive/files/Version5/Alpha/latlon_daily/SST.nc).
#
# To obtain your data, use the [Downloading ECCO Data](https://github.com/ProfMikeWood/ocean_modeling_book/blob/main/tools/Downloading%20ECCO%20Data.ipynb) notebook provided with the course notes. Be sure to edit the fields to obtain the correct data.

# %%
# define the path to the data folder
data_folder = 'E:\CS185C\data\homework_3_data'

# %% [markdown]
# ## Part 2: Create a Single Plot of Sea Surface Temperature
# Before making a movie, its useful to fine tune a single plot to get the details right. Once you've got your plot lookin' good, you can loop through all of the data to generate the panels of your movie.
#
# Here, make a plot of one variable field.
#
# Begin by reading in the longitude, latitude, and SST fields from the netCDF file:

# %%
# read in the data
def load_nc_file(file_path):
    dataset = nc4.Dataset(file_path, mode='r')
    lat = dataset.variables['LATITUDE_T'][:]
    lon = dataset.variables['LONGITUDE_T'][:]
    sst = dataset.variables['SST'][:]
    dataset.close()
    return lat, lon, sst



file_path = 'E:/CS185C/data/homework_3_data/SST_19920101.nc'
latitudes, longitudes, sst_data = load_nc_file(file_path)
# Out:
# C:\Users\shell\AppData\Local\Temp\ipykernel_15388\431835238.py:6: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   sst = dataset.variables['SST'][:]

# %% [markdown]
# Next, find the locations of the longitude and latitude bounds within the global grid for your region of interest:

# %%
# define the longitude/latitude bounds
min_lon = -155
max_lon = -75
min_lat = -20
max_lat = 20

# compute the min/max row/col in the data grid
min_row = np.abs(latitudes - min_lat).argmin()
max_row = np.abs(latitudes - max_lat).argmin()
min_col = np.abs(longitudes - min_lon).argmin()
max_col = np.abs(longitudes - max_lon).argmin()

# %% [markdown]
# Use the row and column bounds to subset the longitude, latitude, and your variable:

# %%
# subset the data
subset_sst = sst_data[0, min_row:max_row, min_col:max_col]

# %% [markdown]
# Finally, make a plot with your subsetted data. For the plot specification, you can use any colormap, data range, and format as you like.
#
# For my example, I find that the temperature plot looks nice with a figure size of (8,4), a turbo colormap, and a data range of 20-31. However, you are encouraged to format your plot to your tastes.

# %%
# make your figure here
subset_sst_flipped = np.flipud(subset_sst)
plt.figure(figsize=(8, 4))
plt.imshow(subset_sst_flipped, cmap='turbo', extent=[min_lon, max_lon, min_lat, max_lat], vmin=20, vmax=30, aspect='auto')
plt.colorbar(label='Temperature (°C)')
plt.title('Equatorial Pacific')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## Part 3: Formulate a Plotting Function
# When you are happy with your plot, make your code into a function that will take the year, month, and day as inputs, and output the figure into a given directory.

# %%
def plot_panel(year, month, day):
    # fill in your function here
    file_name = f"SST_{year}{month:02d}{day:02d}.nc"
    file_path = os.path.join('E:/CS185C/data/homework_3_data', file_name)
    
    if not os.path.exists(file_path):
        print(f"File {file_name} not found!")
        return
    
    dataset = nc4.Dataset(file_path, mode='r')
    latitudes = dataset.variables['LATITUDE_T'][:]
    longitudes = dataset.variables['LONGITUDE_T'][:]
    sst_data = dataset.variables['SST'][:]
    
    min_lon, max_lon = -155, -75
    min_lat, max_lat = -20, 20
    
    min_row = np.abs(latitudes - min_lat).argmin()
    max_row = np.abs(latitudes - max_lat).argmin()
    min_col = np.abs(longitudes - min_lon).argmin()
    max_col = np.abs(longitudes - max_lon).argmin()
    
    subset_sst = sst_data[0, min_row:max_row, min_col:max_col]
    subset_sst_flipped = np.flipud(subset_sst)
    
    plt.figure(figsize=(8, 4))
    plt.imshow(subset_sst_flipped, cmap='turbo', extent=[min_lon, max_lon, min_lat, max_lat], vmin=20, vmax=30, aspect='auto')
    plt.colorbar(label='Temperature (°C)')
    plt.title(f'Equatorial Pacific SST for {year}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    
    output_dir = 'E:/CS185C/output'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)  # Create the directory if it doesn't exist
    
    save_path = os.path.join(output_dir, f'sst_plot_{year}{month:02d}{day:02d}.png')
    plt.savefig(save_path)
    plt.close()
    print(f"Saved plot for {year}-{month:02d}-{day:02d} at {save_path}")

# %% [markdown]
# Once the function is complete, use it to loop through all of the data to make a plot for each day of the year. The following lines of code will form the panels of a data visualization movie when using daily data. If you are using monthly data, update accordingly:

# %%
# loop through the data and make a plot for each day
year = 1992
for month in range(1,13):
    if month in [1,3,5,7,8,10,12]:
        n_days = 31
    elif month in [4,6,9,11]:
        n_days = 30
    else:
        if year%4==0:
            n_days = 29
        else:
            n_days = 28
    for day in range(1,n_days+1):
        plot_panel(year,month,day)
# Out:
# C:\Users\shell\AppData\Local\Temp\ipykernel_15388\685915593.py:13: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   sst_data = dataset.variables['SST'][:]
# Saved plot for 1992-01-01 at E:/CS185C/output\sst_plot_19920101.png
# Saved plot for 1992-01-02 at E:/CS185C/output\sst_plot_19920102.png
# Saved plot for 1992-01-03 at E:/CS185C/output\sst_plot_19920103.png
# Saved plot for 1992-01-04 at E:/CS185C/output\sst_plot_19920104.png
# Saved plot for 1992-01-05 at E:/CS185C/output\sst_plot_19920105.png
# Saved plot for 1992-01-06 at E:/CS185C/output\sst_plot_19920106.png
# Saved plot for 1992-01-07 at E:/CS185C/output\sst_plot_19920107.png
# Saved plot for 1992-01-08 at E:/CS185C/output\sst_plot_19920108.png
# Saved plot for 1992-01-09 at E:/CS185C/output\sst_plot_19920109.png
# Saved plot for 1992-01-10 at E:/CS185C/output\sst_plot_19920110.png
# Saved plot for 1992-01-11 at E:/CS185C/output\sst_plot_19920111.png
# Saved plot for 1992-01-12 at E:/CS185C/output\sst_plot_19920112.png
# Saved plot for 1992-01-13 at E:/CS185C/output\sst_plot_19920113.png
# Saved plot for 1992-01-14 at E:/CS185C/output\sst_plot_19920114.png
# Saved plot for 1992-01-15 at E:/CS185C/output\sst_plot_19920115.png
# Saved plot for 1992-01-16 at E:/CS185C/output\sst_plot_19920116.png
# Saved plot for 1992-01-17 at E:/CS185C/output\sst_plot_19920117.png
# Saved plot for 1992-01-18 at E:/CS185C/output\sst_plot_19920118.png
# Saved plot for 1992-01-19 at E:/CS185C/output\sst_plot_19920119.png
# Saved plot for 1992-01-20 at E:/CS185C/output\sst_plot_19920120.png
# Saved plot for 1992-01-21 at E:/CS185C/output\sst_plot_19920121.png
# Saved plot for 1992-01-22 at E:/CS185C/output\sst_plot_19920122.png
# Saved plot for 1992-01-23 at E:/CS185C/output\sst_plot_19920123.png
# Saved plot for 1992-01-24 at E:/CS185C/output\sst_plot_19920124.png
# Saved plot for 1992-01-25 at E:/CS185C/output\sst_plot_19920125.png
# Saved plot for 1992-01-26 at E:/CS185C/output\sst_plot_19920126.png
# Saved plot for 1992-01-27 at E:/CS185C/output\sst_plot_19920127.png
# Saved plot for 1992-01-28 at E:/CS185C/output\sst_plot_19920128.png
# Saved plot for 1992-01-29 at E:/CS185C/output\sst_plot_19920129.png
# Saved plot for 1992-01-30 at E:/CS185C/output\sst_plot_19920130.png
# Saved plot for 1992-01-31 at E:/CS185C/output\sst_plot_19920131.png
# Saved plot for 1992-02-01 at E:/CS185C/output\sst_plot_19920201.png
# Saved plot for 1992-02-02 at E:/CS185C/output\sst_plot_19920202.png
# Saved plot for 1992-02-03 at E:/CS185C/output\sst_plot_19920203.png
# Saved plot for 1992-02-04 at E:/CS185C/output\sst_plot_19920204.png
# Saved plot for 1992-02-05 at E:/CS185C/output\sst_plot_19920205.png
# Saved plot for 1992-02-06 at E:/CS185C/output\sst_plot_19920206.png
# Saved plot for 1992-02-07 at E:/CS185C/output\sst_plot_19920207.png
# Saved plot for 1992-02-08 at E:/CS185C/output\sst_plot_19920208.png
# Saved plot for 1992-02-09 at E:/CS185C/output\sst_plot_19920209.png
# Saved plot for 1992-02-10 at E:/CS185C/output\sst_plot_19920210.png
# Saved plot for 1992-02-11 at E:/CS185C/output\sst_plot_19920211.png
# Saved plot for 1992-02-12 at E:/CS185C/output\sst_plot_19920212.png
# Saved plot for 1992-02-13 at E:/CS185C/output\sst_plot_19920213.png
# Saved plot for 1992-02-14 at E:/CS185C/output\sst_plot_19920214.png
# Saved plot for 1992-02-15 at E:/CS185C/output\sst_plot_19920215.png
# Saved plot for 1992-02-16 at E:/CS185C/output\sst_plot_19920216.png
# Saved plot for 1992-02-17 at E:/CS185C/output\sst_plot_19920217.png
# Saved plot for 1992-02-18 at E:/CS185C/output\sst_plot_19920218.png
# Saved plot for 1992-02-19 at E:/CS185C/output\sst_plot_19920219.png
# Saved plot for 1992-02-20 at E:/CS185C/output\sst_plot_19920220.png
# Saved plot for 1992-02-21 at E:/CS185C/output\sst_plot_19920221.png
# Saved plot for 1992-02-22 at E:/CS185C/output\sst_plot_19920222.png
# Saved plot for 1992-02-23 at E:/CS185C/output\sst_plot_19920223.png
# Saved plot for 1992-02-24 at E:/CS185C/output\sst_plot_19920224.png
# Saved plot for 1992-02-25 at E:/CS185C/output\sst_plot_19920225.png
# Saved plot for 1992-02-26 at E:/CS185C/output\sst_plot_19920226.png
# Saved plot for 1992-02-27 at E:/CS185C/output\sst_plot_19920227.png
# Saved plot for 1992-02-28 at E:/CS185C/output\sst_plot_19920228.png
# Saved plot for 1992-02-29 at E:/CS185C/output\sst_plot_19920229.png
# Saved plot for 1992-03-01 at E:/CS185C/output\sst_plot_19920301.png
# Saved plot for 1992-03-02 at E:/CS185C/output\sst_plot_19920302.png
# Saved plot for 1992-03-03 at E:/CS185C/output\sst_plot_19920303.png
# Saved plot for 1992-03-04 at E:/CS185C/output\sst_plot_19920304.png
# Saved plot for 1992-03-05 at E:/CS185C/output\sst_plot_19920305.png
# Saved plot for 1992-03-06 at E:/CS185C/output\sst_plot_19920306.png
# Saved plot for 1992-03-07 at E:/CS185C/output\sst_plot_19920307.png
# Saved plot for 1992-03-08 at E:/CS185C/output\sst_plot_19920308.png
# Saved plot for 1992-03-09 at E:/CS185C/output\sst_plot_19920309.png
# Saved plot for 1992-03-10 at E:/CS185C/output\sst_plot_19920310.png
# Saved plot for 1992-03-11 at E:/CS185C/output\sst_plot_19920311.png
# Saved plot for 1992-03-12 at E:/CS185C/output\sst_plot_19920312.png
# Saved plot for 1992-03-13 at E:/CS185C/output\sst_plot_19920313.png
# Saved plot for 1992-03-14 at E:/CS185C/output\sst_plot_19920314.png
# Saved plot for 1992-03-15 at E:/CS185C/output\sst_plot_19920315.png
# Saved plot for 1992-03-16 at E:/CS185C/output\sst_plot_19920316.png
# Saved plot for 1992-03-17 at E:/CS185C/output\sst_plot_19920317.png
# Saved plot for 1992-03-18 at E:/CS185C/output\sst_plot_19920318.png
# Saved plot for 1992-03-19 at E:/CS185C/output\sst_plot_19920319.png
# Saved plot for 1992-03-20 at E:/CS185C/output\sst_plot_19920320.png
# Saved plot for 1992-03-21 at E:/CS185C/output\sst_plot_19920321.png
# Saved plot for 1992-03-22 at E:/CS185C/output\sst_plot_19920322.png
# Saved plot for 1992-03-23 at E:/CS185C/output\sst_plot_19920323.png
# Saved plot for 1992-03-24 at E:/CS185C/output\sst_plot_19920324.png
# Saved plot for 1992-03-25 at E:/CS185C/output\sst_plot_19920325.png
# Saved plot for 1992-03-26 at E:/CS185C/output\sst_plot_19920326.png
# Saved plot for 1992-03-27 at E:/CS185C/output\sst_plot_19920327.png
# Saved plot for 1992-03-28 at E:/CS185C/output\sst_plot_19920328.png
# Saved plot for 1992-03-29 at E:/CS185C/output\sst_plot_19920329.png
# Saved plot for 1992-03-30 at E:/CS185C/output\sst_plot_19920330.png
# Saved plot for 1992-03-31 at E:/CS185C/output\sst_plot_19920331.png
# Saved plot for 1992-04-01 at E:/CS185C/output\sst_plot_19920401.png
# Saved plot for 1992-04-02 at E:/CS185C/output\sst_plot_19920402.png
# Saved plot for 1992-04-03 at E:/CS185C/output\sst_plot_19920403.png
# Saved plot for 1992-04-04 at E:/CS185C/output\sst_plot_19920404.png
# Saved plot for 1992-04-05 at E:/CS185C/output\sst_plot_19920405.png
# Saved plot for 1992-04-06 at E:/CS185C/output\sst_plot_19920406.png
# Saved plot for 1992-04-07 at E:/CS185C/output\sst_plot_19920407.png
# Saved plot for 1992-04-08 at E:/CS185C/output\sst_plot_19920408.png
# Saved plot for 1992-04-09 at E:/CS185C/output\sst_plot_19920409.png
# Saved plot for 1992-04-10 at E:/CS185C/output\sst_plot_19920410.png
# Saved plot for 1992-04-11 at E:/CS185C/output\sst_plot_19920411.png
# Saved plot for 1992-04-12 at E:/CS185C/output\sst_plot_19920412.png
# Saved plot for 1992-04-13 at E:/CS185C/output\sst_plot_19920413.png
# Saved plot for 1992-04-14 at E:/CS185C/output\sst_plot_19920414.png
# Saved plot for 1992-04-15 at E:/CS185C/output\sst_plot_19920415.png
# Saved plot for 1992-04-16 at E:/CS185C/output\sst_plot_19920416.png
# Saved plot for 1992-04-17 at E:/CS185C/output\sst_plot_19920417.png
# Saved plot for 1992-04-18 at E:/CS185C/output\sst_plot_19920418.png
# Saved plot for 1992-04-19 at E:/CS185C/output\sst_plot_19920419.png
# Saved plot for 1992-04-20 at E:/CS185C/output\sst_plot_19920420.png
# Saved plot for 1992-04-21 at E:/CS185C/output\sst_plot_19920421.png
# Saved plot for 1992-04-22 at E:/CS185C/output\sst_plot_19920422.png
# Saved plot for 1992-04-23 at E:/CS185C/output\sst_plot_19920423.png
# Saved plot for 1992-04-24 at E:/CS185C/output\sst_plot_19920424.png
# Saved plot for 1992-04-25 at E:/CS185C/output\sst_plot_19920425.png
# Saved plot for 1992-04-26 at E:/CS185C/output\sst_plot_19920426.png
# Saved plot for 1992-04-27 at E:/CS185C/output\sst_plot_19920427.png
# Saved plot for 1992-04-28 at E:/CS185C/output\sst_plot_19920428.png
# Saved plot for 1992-04-29 at E:/CS185C/output\sst_plot_19920429.png
# Saved plot for 1992-04-30 at E:/CS185C/output\sst_plot_19920430.png
# Saved plot for 1992-05-01 at E:/CS185C/output\sst_plot_19920501.png
# Saved plot for 1992-05-02 at E:/CS185C/output\sst_plot_19920502.png
# Saved plot for 1992-05-03 at E:/CS185C/output\sst_plot_19920503.png
# Saved plot for 1992-05-04 at E:/CS185C/output\sst_plot_19920504.png
# Saved plot for 1992-05-05 at E:/CS185C/output\sst_plot_19920505.png
# Saved plot for 1992-05-06 at E:/CS185C/output\sst_plot_19920506.png
# Saved plot for 1992-05-07 at E:/CS185C/output\sst_plot_19920507.png
# Saved plot for 1992-05-08 at E:/CS185C/output\sst_plot_19920508.png
# Saved plot for 1992-05-09 at E:/CS185C/output\sst_plot_19920509.png
# Saved plot for 1992-05-10 at E:/CS185C/output\sst_plot_19920510.png
# Saved plot for 1992-05-11 at E:/CS185C/output\sst_plot_19920511.png
# Saved plot for 1992-05-12 at E:/CS185C/output\sst_plot_19920512.png
# Saved plot for 1992-05-13 at E:/CS185C/output\sst_plot_19920513.png
# Saved plot for 1992-05-14 at E:/CS185C/output\sst_plot_19920514.png
# Saved plot for 1992-05-15 at E:/CS185C/output\sst_plot_19920515.png
# Saved plot for 1992-05-16 at E:/CS185C/output\sst_plot_19920516.png
# Saved plot for 1992-05-17 at E:/CS185C/output\sst_plot_19920517.png
# Saved plot for 1992-05-18 at E:/CS185C/output\sst_plot_19920518.png
# Saved plot for 1992-05-19 at E:/CS185C/output\sst_plot_19920519.png
# Saved plot for 1992-05-20 at E:/CS185C/output\sst_plot_19920520.png
# Saved plot for 1992-05-21 at E:/CS185C/output\sst_plot_19920521.png
# Saved plot for 1992-05-22 at E:/CS185C/output\sst_plot_19920522.png
# Saved plot for 1992-05-23 at E:/CS185C/output\sst_plot_19920523.png
# Saved plot for 1992-05-24 at E:/CS185C/output\sst_plot_19920524.png
# Saved plot for 1992-05-25 at E:/CS185C/output\sst_plot_19920525.png
# Saved plot for 1992-05-26 at E:/CS185C/output\sst_plot_19920526.png
# Saved plot for 1992-05-27 at E:/CS185C/output\sst_plot_19920527.png
# Saved plot for 1992-05-28 at E:/CS185C/output\sst_plot_19920528.png
# Saved plot for 1992-05-29 at E:/CS185C/output\sst_plot_19920529.png
# Saved plot for 1992-05-30 at E:/CS185C/output\sst_plot_19920530.png
# Saved plot for 1992-05-31 at E:/CS185C/output\sst_plot_19920531.png
# Saved plot for 1992-06-01 at E:/CS185C/output\sst_plot_19920601.png
# Saved plot for 1992-06-02 at E:/CS185C/output\sst_plot_19920602.png
# Saved plot for 1992-06-03 at E:/CS185C/output\sst_plot_19920603.png
# Saved plot for 1992-06-04 at E:/CS185C/output\sst_plot_19920604.png
# Saved plot for 1992-06-05 at E:/CS185C/output\sst_plot_19920605.png
# Saved plot for 1992-06-06 at E:/CS185C/output\sst_plot_19920606.png
# Saved plot for 1992-06-07 at E:/CS185C/output\sst_plot_19920607.png
# Saved plot for 1992-06-08 at E:/CS185C/output\sst_plot_19920608.png
# Saved plot for 1992-06-09 at E:/CS185C/output\sst_plot_19920609.png
# Saved plot for 1992-06-10 at E:/CS185C/output\sst_plot_19920610.png
# Saved plot for 1992-06-11 at E:/CS185C/output\sst_plot_19920611.png
# Saved plot for 1992-06-12 at E:/CS185C/output\sst_plot_19920612.png
# Saved plot for 1992-06-13 at E:/CS185C/output\sst_plot_19920613.png
# Saved plot for 1992-06-14 at E:/CS185C/output\sst_plot_19920614.png
# Saved plot for 1992-06-15 at E:/CS185C/output\sst_plot_19920615.png
# Saved plot for 1992-06-16 at E:/CS185C/output\sst_plot_19920616.png
# Saved plot for 1992-06-17 at E:/CS185C/output\sst_plot_19920617.png
# Saved plot for 1992-06-18 at E:/CS185C/output\sst_plot_19920618.png
# Saved plot for 1992-06-19 at E:/CS185C/output\sst_plot_19920619.png
# Saved plot for 1992-06-20 at E:/CS185C/output\sst_plot_19920620.png
# Saved plot for 1992-06-21 at E:/CS185C/output\sst_plot_19920621.png
# Saved plot for 1992-06-22 at E:/CS185C/output\sst_plot_19920622.png
# Saved plot for 1992-06-23 at E:/CS185C/output\sst_plot_19920623.png
# Saved plot for 1992-06-24 at E:/CS185C/output\sst_plot_19920624.png
# Saved plot for 1992-06-25 at E:/CS185C/output\sst_plot_19920625.png
# Saved plot for 1992-06-26 at E:/CS185C/output\sst_plot_19920626.png
# Saved plot for 1992-06-27 at E:/CS185C/output\sst_plot_19920627.png
# Saved plot for 1992-06-28 at E:/CS185C/output\sst_plot_19920628.png
# Saved plot for 1992-06-29 at E:/CS185C/output\sst_plot_19920629.png
# Saved plot for 1992-06-30 at E:/CS185C/output\sst_plot_19920630.png
# Saved plot for 1992-07-01 at E:/CS185C/output\sst_plot_19920701.png
# Saved plot for 1992-07-02 at E:/CS185C/output\sst_plot_19920702.png
# Saved plot for 1992-07-03 at E:/CS185C/output\sst_plot_19920703.png
# Saved plot for 1992-07-04 at E:/CS185C/output\sst_plot_19920704.png
# Saved plot for 1992-07-05 at E:/CS185C/output\sst_plot_19920705.png
# Saved plot for 1992-07-06 at E:/CS185C/output\sst_plot_19920706.png
# Saved plot for 1992-07-07 at E:/CS185C/output\sst_plot_19920707.png
# Saved plot for 1992-07-08 at E:/CS185C/output\sst_plot_19920708.png
# Saved plot for 1992-07-09 at E:/CS185C/output\sst_plot_19920709.png
# Saved plot for 1992-07-10 at E:/CS185C/output\sst_plot_19920710.png
# Saved plot for 1992-07-11 at E:/CS185C/output\sst_plot_19920711.png
# Saved plot for 1992-07-12 at E:/CS185C/output\sst_plot_19920712.png
# Saved plot for 1992-07-13 at E:/CS185C/output\sst_plot_19920713.png
# Saved plot for 1992-07-14 at E:/CS185C/output\sst_plot_19920714.png
# Saved plot for 1992-07-15 at E:/CS185C/output\sst_plot_19920715.png
# Saved plot for 1992-07-16 at E:/CS185C/output\sst_plot_19920716.png
# Saved plot for 1992-07-17 at E:/CS185C/output\sst_plot_19920717.png
# Saved plot for 1992-07-18 at E:/CS185C/output\sst_plot_19920718.png
# Saved plot for 1992-07-19 at E:/CS185C/output\sst_plot_19920719.png
# Saved plot for 1992-07-20 at E:/CS185C/output\sst_plot_19920720.png
# Saved plot for 1992-07-21 at E:/CS185C/output\sst_plot_19920721.png
# Saved plot for 1992-07-22 at E:/CS185C/output\sst_plot_19920722.png
# Saved plot for 1992-07-23 at E:/CS185C/output\sst_plot_19920723.png
# Saved plot for 1992-07-24 at E:/CS185C/output\sst_plot_19920724.png
# Saved plot for 1992-07-25 at E:/CS185C/output\sst_plot_19920725.png
# Saved plot for 1992-07-26 at E:/CS185C/output\sst_plot_19920726.png
# Saved plot for 1992-07-27 at E:/CS185C/output\sst_plot_19920727.png
# Saved plot for 1992-07-28 at E:/CS185C/output\sst_plot_19920728.png
# Saved plot for 1992-07-29 at E:/CS185C/output\sst_plot_19920729.png
# Saved plot for 1992-07-30 at E:/CS185C/output\sst_plot_19920730.png
# Saved plot for 1992-07-31 at E:/CS185C/output\sst_plot_19920731.png
# Saved plot for 1992-08-01 at E:/CS185C/output\sst_plot_19920801.png
# Saved plot for 1992-08-02 at E:/CS185C/output\sst_plot_19920802.png
# Saved plot for 1992-08-03 at E:/CS185C/output\sst_plot_19920803.png
# Saved plot for 1992-08-04 at E:/CS185C/output\sst_plot_19920804.png
# Saved plot for 1992-08-05 at E:/CS185C/output\sst_plot_19920805.png
# Saved plot for 1992-08-06 at E:/CS185C/output\sst_plot_19920806.png
# Saved plot for 1992-08-07 at E:/CS185C/output\sst_plot_19920807.png
# Saved plot for 1992-08-08 at E:/CS185C/output\sst_plot_19920808.png
# Saved plot for 1992-08-09 at E:/CS185C/output\sst_plot_19920809.png
# Saved plot for 1992-08-10 at E:/CS185C/output\sst_plot_19920810.png
# Saved plot for 1992-08-11 at E:/CS185C/output\sst_plot_19920811.png
# Saved plot for 1992-08-12 at E:/CS185C/output\sst_plot_19920812.png
# Saved plot for 1992-08-13 at E:/CS185C/output\sst_plot_19920813.png
# Saved plot for 1992-08-14 at E:/CS185C/output\sst_plot_19920814.png
# Saved plot for 1992-08-15 at E:/CS185C/output\sst_plot_19920815.png
# Saved plot for 1992-08-16 at E:/CS185C/output\sst_plot_19920816.png
# Saved plot for 1992-08-17 at E:/CS185C/output\sst_plot_19920817.png
# Saved plot for 1992-08-18 at E:/CS185C/output\sst_plot_19920818.png
# Saved plot for 1992-08-19 at E:/CS185C/output\sst_plot_19920819.png
# Saved plot for 1992-08-20 at E:/CS185C/output\sst_plot_19920820.png
# Saved plot for 1992-08-21 at E:/CS185C/output\sst_plot_19920821.png
# Saved plot for 1992-08-22 at E:/CS185C/output\sst_plot_19920822.png
# Saved plot for 1992-08-23 at E:/CS185C/output\sst_plot_19920823.png
# Saved plot for 1992-08-24 at E:/CS185C/output\sst_plot_19920824.png
# Saved plot for 1992-08-25 at E:/CS185C/output\sst_plot_19920825.png
# Saved plot for 1992-08-26 at E:/CS185C/output\sst_plot_19920826.png
# Saved plot for 1992-08-27 at E:/CS185C/output\sst_plot_19920827.png
# Saved plot for 1992-08-28 at E:/CS185C/output\sst_plot_19920828.png
# Saved plot for 1992-08-29 at E:/CS185C/output\sst_plot_19920829.png
# Saved plot for 1992-08-30 at E:/CS185C/output\sst_plot_19920830.png
# Saved plot for 1992-08-31 at E:/CS185C/output\sst_plot_19920831.png
# Saved plot for 1992-09-01 at E:/CS185C/output\sst_plot_19920901.png
# Saved plot for 1992-09-02 at E:/CS185C/output\sst_plot_19920902.png
# Saved plot for 1992-09-03 at E:/CS185C/output\sst_plot_19920903.png
# Saved plot for 1992-09-04 at E:/CS185C/output\sst_plot_19920904.png
# Saved plot for 1992-09-05 at E:/CS185C/output\sst_plot_19920905.png
# Saved plot for 1992-09-06 at E:/CS185C/output\sst_plot_19920906.png
# Saved plot for 1992-09-07 at E:/CS185C/output\sst_plot_19920907.png
# Saved plot for 1992-09-08 at E:/CS185C/output\sst_plot_19920908.png
# Saved plot for 1992-09-09 at E:/CS185C/output\sst_plot_19920909.png
# Saved plot for 1992-09-10 at E:/CS185C/output\sst_plot_19920910.png
# Saved plot for 1992-09-11 at E:/CS185C/output\sst_plot_19920911.png
# Saved plot for 1992-09-12 at E:/CS185C/output\sst_plot_19920912.png
# Saved plot for 1992-09-13 at E:/CS185C/output\sst_plot_19920913.png
# Saved plot for 1992-09-14 at E:/CS185C/output\sst_plot_19920914.png
# Saved plot for 1992-09-15 at E:/CS185C/output\sst_plot_19920915.png
# Saved plot for 1992-09-16 at E:/CS185C/output\sst_plot_19920916.png
# Saved plot for 1992-09-17 at E:/CS185C/output\sst_plot_19920917.png
# Saved plot for 1992-09-18 at E:/CS185C/output\sst_plot_19920918.png
# Saved plot for 1992-09-19 at E:/CS185C/output\sst_plot_19920919.png
# Saved plot for 1992-09-20 at E:/CS185C/output\sst_plot_19920920.png
# Saved plot for 1992-09-21 at E:/CS185C/output\sst_plot_19920921.png
# Saved plot for 1992-09-22 at E:/CS185C/output\sst_plot_19920922.png
# Saved plot for 1992-09-23 at E:/CS185C/output\sst_plot_19920923.png
# Saved plot for 1992-09-24 at E:/CS185C/output\sst_plot_19920924.png
# Saved plot for 1992-09-25 at E:/CS185C/output\sst_plot_19920925.png
# Saved plot for 1992-09-26 at E:/CS185C/output\sst_plot_19920926.png
# Saved plot for 1992-09-27 at E:/CS185C/output\sst_plot_19920927.png
# Saved plot for 1992-09-28 at E:/CS185C/output\sst_plot_19920928.png
# Saved plot for 1992-09-29 at E:/CS185C/output\sst_plot_19920929.png
# Saved plot for 1992-09-30 at E:/CS185C/output\sst_plot_19920930.png
# Saved plot for 1992-10-01 at E:/CS185C/output\sst_plot_19921001.png
# Saved plot for 1992-10-02 at E:/CS185C/output\sst_plot_19921002.png
# Saved plot for 1992-10-03 at E:/CS185C/output\sst_plot_19921003.png
# Saved plot for 1992-10-04 at E:/CS185C/output\sst_plot_19921004.png
# Saved plot for 1992-10-05 at E:/CS185C/output\sst_plot_19921005.png
# Saved plot for 1992-10-06 at E:/CS185C/output\sst_plot_19921006.png
# Saved plot for 1992-10-07 at E:/CS185C/output\sst_plot_19921007.png
# Saved plot for 1992-10-08 at E:/CS185C/output\sst_plot_19921008.png
# Saved plot for 1992-10-09 at E:/CS185C/output\sst_plot_19921009.png
# Saved plot for 1992-10-10 at E:/CS185C/output\sst_plot_19921010.png
# Saved plot for 1992-10-11 at E:/CS185C/output\sst_plot_19921011.png
# Saved plot for 1992-10-12 at E:/CS185C/output\sst_plot_19921012.png
# Saved plot for 1992-10-13 at E:/CS185C/output\sst_plot_19921013.png
# Saved plot for 1992-10-14 at E:/CS185C/output\sst_plot_19921014.png
# Saved plot for 1992-10-15 at E:/CS185C/output\sst_plot_19921015.png
# Saved plot for 1992-10-16 at E:/CS185C/output\sst_plot_19921016.png
# Saved plot for 1992-10-17 at E:/CS185C/output\sst_plot_19921017.png
# Saved plot for 1992-10-18 at E:/CS185C/output\sst_plot_19921018.png
# Saved plot for 1992-10-19 at E:/CS185C/output\sst_plot_19921019.png
# Saved plot for 1992-10-20 at E:/CS185C/output\sst_plot_19921020.png
# Saved plot for 1992-10-21 at E:/CS185C/output\sst_plot_19921021.png
# Saved plot for 1992-10-22 at E:/CS185C/output\sst_plot_19921022.png
# Saved plot for 1992-10-23 at E:/CS185C/output\sst_plot_19921023.png
# Saved plot for 1992-10-24 at E:/CS185C/output\sst_plot_19921024.png
# Saved plot for 1992-10-25 at E:/CS185C/output\sst_plot_19921025.png
# Saved plot for 1992-10-26 at E:/CS185C/output\sst_plot_19921026.png
# Saved plot for 1992-10-27 at E:/CS185C/output\sst_plot_19921027.png
# Saved plot for 1992-10-28 at E:/CS185C/output\sst_plot_19921028.png
# Saved plot for 1992-10-29 at E:/CS185C/output\sst_plot_19921029.png
# Saved plot for 1992-10-30 at E:/CS185C/output\sst_plot_19921030.png
# Saved plot for 1992-10-31 at E:/CS185C/output\sst_plot_19921031.png
# Saved plot for 1992-11-01 at E:/CS185C/output\sst_plot_19921101.png
# Saved plot for 1992-11-02 at E:/CS185C/output\sst_plot_19921102.png
# Saved plot for 1992-11-03 at E:/CS185C/output\sst_plot_19921103.png
# Saved plot for 1992-11-04 at E:/CS185C/output\sst_plot_19921104.png
# Saved plot for 1992-11-05 at E:/CS185C/output\sst_plot_19921105.png
# Saved plot for 1992-11-06 at E:/CS185C/output\sst_plot_19921106.png
# Saved plot for 1992-11-07 at E:/CS185C/output\sst_plot_19921107.png
# Saved plot for 1992-11-08 at E:/CS185C/output\sst_plot_19921108.png
# Saved plot for 1992-11-09 at E:/CS185C/output\sst_plot_19921109.png
# Saved plot for 1992-11-10 at E:/CS185C/output\sst_plot_19921110.png
# Saved plot for 1992-11-11 at E:/CS185C/output\sst_plot_19921111.png
# Saved plot for 1992-11-12 at E:/CS185C/output\sst_plot_19921112.png
# Saved plot for 1992-11-13 at E:/CS185C/output\sst_plot_19921113.png
# Saved plot for 1992-11-14 at E:/CS185C/output\sst_plot_19921114.png
# Saved plot for 1992-11-15 at E:/CS185C/output\sst_plot_19921115.png
# Saved plot for 1992-11-16 at E:/CS185C/output\sst_plot_19921116.png
# Saved plot for 1992-11-17 at E:/CS185C/output\sst_plot_19921117.png
# Saved plot for 1992-11-18 at E:/CS185C/output\sst_plot_19921118.png
# Saved plot for 1992-11-19 at E:/CS185C/output\sst_plot_19921119.png
# Saved plot for 1992-11-20 at E:/CS185C/output\sst_plot_19921120.png
# Saved plot for 1992-11-21 at E:/CS185C/output\sst_plot_19921121.png
# Saved plot for 1992-11-22 at E:/CS185C/output\sst_plot_19921122.png
# Saved plot for 1992-11-23 at E:/CS185C/output\sst_plot_19921123.png
# Saved plot for 1992-11-24 at E:/CS185C/output\sst_plot_19921124.png
# Saved plot for 1992-11-25 at E:/CS185C/output\sst_plot_19921125.png
# Saved plot for 1992-11-26 at E:/CS185C/output\sst_plot_19921126.png
# Saved plot for 1992-11-27 at E:/CS185C/output\sst_plot_19921127.png
# Saved plot for 1992-11-28 at E:/CS185C/output\sst_plot_19921128.png
# Saved plot for 1992-11-29 at E:/CS185C/output\sst_plot_19921129.png
# Saved plot for 1992-11-30 at E:/CS185C/output\sst_plot_19921130.png
# Saved plot for 1992-12-01 at E:/CS185C/output\sst_plot_19921201.png
# Saved plot for 1992-12-02 at E:/CS185C/output\sst_plot_19921202.png
# Saved plot for 1992-12-03 at E:/CS185C/output\sst_plot_19921203.png
# Saved plot for 1992-12-04 at E:/CS185C/output\sst_plot_19921204.png
# Saved plot for 1992-12-05 at E:/CS185C/output\sst_plot_19921205.png
# Saved plot for 1992-12-06 at E:/CS185C/output\sst_plot_19921206.png
# Saved plot for 1992-12-07 at E:/CS185C/output\sst_plot_19921207.png
# Saved plot for 1992-12-08 at E:/CS185C/output\sst_plot_19921208.png
# Saved plot for 1992-12-09 at E:/CS185C/output\sst_plot_19921209.png
# Saved plot for 1992-12-10 at E:/CS185C/output\sst_plot_19921210.png
# Saved plot for 1992-12-11 at E:/CS185C/output\sst_plot_19921211.png
# Saved plot for 1992-12-12 at E:/CS185C/output\sst_plot_19921212.png
# Saved plot for 1992-12-13 at E:/CS185C/output\sst_plot_19921213.png
# Saved plot for 1992-12-14 at E:/CS185C/output\sst_plot_19921214.png
# Saved plot for 1992-12-15 at E:/CS185C/output\sst_plot_19921215.png
# Saved plot for 1992-12-16 at E:/CS185C/output\sst_plot_19921216.png
# Saved plot for 1992-12-17 at E:/CS185C/output\sst_plot_19921217.png
# Saved plot for 1992-12-18 at E:/CS185C/output\sst_plot_19921218.png
# Saved plot for 1992-12-19 at E:/CS185C/output\sst_plot_19921219.png
# Saved plot for 1992-12-20 at E:/CS185C/output\sst_plot_19921220.png
# Saved plot for 1992-12-21 at E:/CS185C/output\sst_plot_19921221.png
# Saved plot for 1992-12-22 at E:/CS185C/output\sst_plot_19921222.png
# Saved plot for 1992-12-23 at E:/CS185C/output\sst_plot_19921223.png
# Saved plot for 1992-12-24 at E:/CS185C/output\sst_plot_19921224.png
# Saved plot for 1992-12-25 at E:/CS185C/output\sst_plot_19921225.png
# Saved plot for 1992-12-26 at E:/CS185C/output\sst_plot_19921226.png
# Saved plot for 1992-12-27 at E:/CS185C/output\sst_plot_19921227.png
# Saved plot for 1992-12-28 at E:/CS185C/output\sst_plot_19921228.png
# Saved plot for 1992-12-29 at E:/CS185C/output\sst_plot_19921229.png
# Saved plot for 1992-12-30 at E:/CS185C/output\sst_plot_19921230.png
# Saved plot for 1992-12-31 at E:/CS185C/output\sst_plot_19921231.png

# %% [markdown]
# ## Part 4: Compile Panels into a Movie
# After creating all of the panels, stitch them together into a movie using moviepy:

# %%
import os
from moviepy.video.io.ImageSequenceClip import ImageSequenceClip

# make a list of files for each movie panel
output_dir = 'E:/CS185C/output'

# sort the panels
image_files = [os.path.join(output_dir, img) for img in sorted(os.listdir(output_dir)) if img.endswith('.png')]

# %%
# set the frames per second
fps = 15 

# use the ImageSequenceClip module to set up the clip
clip = ImageSequenceClip(image_files, fps=fps)

# write the video to a file
output_video_path = 'E:/CS185C/ocean_movie.mp4'  
clip.write_videofile(output_video_path, codec='libx264')

print(f"Movie created successfully: {output_video_path}")
# Out:
# Moviepy - Building video E:/CS185C/ocean_movie.mp4.
# Moviepy - Writing video E:/CS185C/ocean_movie.mp4
# Moviepy - Done !
# Moviepy - video ready E:/CS185C/ocean_movie.mp4
# Movie created successfully: E:/CS185C/ocean_movie.mp4

# %% [markdown]
# ## Part 5: Interpret Features in the Movie
# A movie gives a good visualization of the physical processes occurring in a model. Describe one feature you see in the movie and relate it to an oceanographic feature. It could be a feature discussed in class or another feature you noticed and researched on your own.
#
# Answer:  From the movie I see that there is warming in the sea surface temperatures in the equatorial pacific which stretches from the coast of South America towards the central and western Pacific Ocean. This is also known as an el nino, which is when trade winds are weakened which allow for warm water from the western pacific to move eastward.
